# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
cities=pd.read_csv("california_cities.csv")
cities.head(5)
# Out:
#    Unnamed: 0         city       latd       longd  elevation_m  elevation_ft  \
# 0           0     Adelanto  34.576111 -117.432778        875.0        2871.0
# 1           1  AgouraHills  34.153333 -118.761667        281.0         922.0
# 2           2      Alameda  37.756111 -122.274444          NaN          33.0
# 3           3       Albany  37.886944 -122.297778          NaN          43.0
# 4           4     Alhambra  34.081944 -118.135000        150.0         492.0
#
#    population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 0             31765            56.027           56.009             0.018
# 1             20330             7.822            7.793             0.029
# 2             75467            22.960           10.611            12.349
# 3             18969             5.465            1.788             3.677
# 4             83089             7.632            7.631             0.001
#
# ...

# %%
plt.style.available
plt.style.use('seaborn-v0_8-whitegrid')
plt.plot()
# Out:
# []

# %%
x=[1,2,3,4]
y=[10,8,6,9]
plt.plot(x,y,color="red")

# %%
#pylot API
x=np.linspace(0,10,1000)
x
# Out:
# array([ 0.        ,  0.01001001,  0.02002002,  0.03003003,  0.04004004,
#         0.05005005,  0.06006006,  0.07007007,  0.08008008,  0.09009009,
#         0.1001001 ,  0.11011011,  0.12012012,  0.13013013,  0.14014014,
#         0.15015015,  0.16016016,  0.17017017,  0.18018018,  0.19019019,
#         0.2002002 ,  0.21021021,  0.22022022,  0.23023023,  0.24024024,
#         0.25025025,  0.26026026,  0.27027027,  0.28028028,  0.29029029,
#         0.3003003 ,  0.31031031,  0.32032032,  0.33033033,  0.34034034,
#         0.35035035,  0.36036036,  0.37037037,  0.38038038,  0.39039039,
#         0.4004004 ,  0.41041041,  0.42042042,  0.43043043,  0.44044044,
#         0.45045045,  0.46046046,  0.47047047,  0.48048048,  0.49049049,
#         0.5005005 ,  0.51051051,  0.52052052,  0.53053053,  0.54054054,
#         0.55055055,  0.56056056,  0.57057057,  0.58058058,  0.59059059,
#         0.6006006 ,  0.61061061,  0.62062062,  0.63063063,  0.64064064,
# ...

# %%
#vd cho y = sinx
plt.plot(x,np.sin(x),color='green')
plt.xlabel("trục X")
plt.ylabel("trục Y")
# Out:
# Text(0, 0.5, 'trục Y')

# %%
# giới hạn đồ thị x t 0 đến 4 y từ -1 đến 0.75
plt.xlim(0,4)
plt.ylim(-1,0.75)
plt.plot(x,np.sin(x))

# %%
plt.xlabel("trục X")
plt.ylabel("trục Y")
plt.xlim(0,4)
plt.ylim(-1,0.75)
plt.plot(x,np.sin(x))
plt.plot(x,np.sin(x),color='green',linestyle='dashed')

# %%
x=np.linspace(0,10,1000)
y=np.sin(x)
z=np.cos(x)
plt.title('SinX and CosX')
plt.plot(x,y,label='sinx', color='green', linestyle='dashed')
plt.plot(x,z,label='cosx')
plt.legend() #ghi chú thích cho các label trên
plt.xlabel('X')
plt.ylabel('Y')
plt.axis('equal')
# Out:
# (-0.5, 10.5, -1.0999987378908789, 1.0999999398995657)

# %%
#OO API HƯỚNG ĐỐI TUƯỢNG
x=[1,2,3,4]
y=[11,22,33,44]

fg,ax=plt.subplots(figsize=(5,5))
ax.plot(x,y)
ax.set(title='A simple plot',xlabel='trục x',ylabel='trục y')
# Out:
# [Text(0.5, 1.0, 'A simple plot'),
#  Text(0.5, 0, 'trục x'),
#  Text(0, 0.5, 'trục y')]

# %%
#đồ thị phổ biến line,rời rac scatter,bar,hist,subplots...
#topic1: line chart
x=np.linspace(0,10,100)
x[:5]
# Out:
# array([0.       , 0.1010101, 0.2020202, 0.3030303, 0.4040404])

# %%
fig,ax=plt.subplots()
ax.plot(x,x**3) #y=x^3

# %%
#topic 2: scatter
plt.scatter(x,np.exp(x)) #y=e^x

# %%
rng=np.random.RandomState(0)
x=rng.randn(100)
y=rng.randn(100)
colors=rng.rand(100)
size=1000*rng.rand(100)
fix,ax=plt.subplots()
img1=ax.scatter(x,y,size,colors,cmap='viridis',alpha=0.3)
fix.colorbar(img1)

# %%
#bar chart
soft_drink_price={"Cam":12,"Cola":10,"Cafe":15}
fig,ax=plt.subplots()
ax.bar(soft_drink_price.keys(),soft_drink_price.values())
ax.set(title='Bách hóa xanh',ylabel='Gía')
# Out:
# [Text(0.5, 1.0, 'Bách hóa xanh'), Text(0, 0.5, 'Gía')]

# %%
#vẽ theo trục ngang
fig,ax=plt.subplots()
ax.barh(list(soft_drink_price.keys()),list(soft_drink_price.values()))
# Out:
# <BarContainer object of 3 artists>

# %%
#histogram
student_height=np.random.normal(170, 10, 250)
student_height
plt.hist(student_height)
# Out:
# (array([ 5., 15., 35., 36., 61., 43., 33., 14.,  7.,  1.]),
#  array([145.1151866 , 150.47680018, 155.83841376, 161.20002735,
#         166.56164093, 171.92325451, 177.28486809, 182.64648168,
#         188.00809526, 193.36970884, 198.73132242]),
#  <BarContainer object of 10 artists>)

# %%
#Subplot
fig,((ax1,ax2),(ax3,ax4))=plt.subplots(nrows=2,ncols=2,figsize=(10,5)) #ngang 10, cao là 5
ax1.plot(x,x/2)
ax1.plot(x,x*2)

ax2.scatter(np.random.random(10),np.random.random(10))
ax3.bar(soft_drink_price.keys(),soft_drink_price.values())
ax4.hist(student_height)
# Out:
# (array([ 5., 15., 35., 36., 61., 43., 33., 14.,  7.,  1.]),
#  array([145.1151866 , 150.47680018, 155.83841376, 161.20002735,
#         166.56164093, 171.92325451, 177.28486809, 182.64648168,
#         188.00809526, 193.36970884, 198.73132242]),
#  <BarContainer object of 10 artists>)

# %%
#option 2
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(10,5))
ax[0,0].plot(x,x/2)
ax[0,0].plot(x,x*2)

ax[0,1].scatter(np.random.random(10),np.random.random(10))
ax[1,0].bar(soft_drink_price.keys(),soft_drink_price.values())
ax[1,1].hist(student_height)
# Out:
# (array([ 5., 15., 35., 36., 61., 43., 33., 14.,  7.,  1.]),
#  array([145.1151866 , 150.47680018, 155.83841376, 161.20002735,
#         166.56164093, 171.92325451, 177.28486809, 182.64648168,
#         188.00809526, 193.36970884, 198.73132242]),
#  <BarContainer object of 10 artists>)
